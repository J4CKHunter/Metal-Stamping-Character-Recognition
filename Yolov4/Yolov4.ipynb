# %% [markdown]
# ##**Drive Bağlantısı**

# %%
from google.colab import drive # Drive hesabımızı ekliyoruz
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ##**Zip'ten Çıkarma**

# %%
# !unzip "/content/gdrive/MyDrive/darknet.zip" -d "/content/" # Darknet dosyamızı zipten çıkarıyoruz
# Out:
# Görüntülenen çıkış son 5000 satıra kısaltıldı.
#   inflating: /content/darknet/cfg/csdarknet53-omega.cfg
#   inflating: /content/__MACOSX/darknet/cfg/._csdarknet53-omega.cfg
#   inflating: /content/darknet/cfg/yolov2-voc.cfg
#   inflating: /content/__MACOSX/darknet/cfg/._yolov2-voc.cfg
#   inflating: /content/darknet/cfg/openimages.data
#   inflating: /content/__MACOSX/darknet/cfg/._openimages.data
#   inflating: /content/darknet/cfg/yolov4-tiny_contrastive.cfg
#   inflating: /content/__MACOSX/darknet/cfg/._yolov4-tiny_contrastive.cfg
#   inflating: /content/darknet/cfg/yolo9000.cfg
#   inflating: /content/__MACOSX/darknet/cfg/._yolo9000.cfg
#   inflating: /content/darknet/cfg/yolov3-voc.cfg
#   inflating: /content/__MACOSX/darknet/cfg/._yolov3-voc.cfg
#   inflating: /content/darknet/cfg/darknet19_448.cfg
#   inflating: /content/__MACOSX/darknet/cfg/._darknet19_448.cfg
#   inflating: /content/darknet/cfg/resnet50.cfg
#   inflating: /content/__MACOSX/darknet/cfg/._resnet50.cfg
# ...

# %% [markdown]
# ###**Make**
# Çalıştırma (eğer sonu lcudann -lstdc++ ile bitiyorsa herhangi bir sorun yoktur )

# %%
# darknet'i oluşturur, böylece darknet yürütülebilir dosyasını nesne dedektörlerini çalıştırmak veya eğitmek için kullanabilirsiniz
# %cd /content/darknet
# !make
# Out:
# /content/darknet
# mkdir -p ./obj/
# mkdir -p backup
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:946:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1147:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
# ...

# %% [markdown]
# ###**Backup Bağlantısı**

# %%
# !rm /content/darknet/backup -r # Darknetin içindeki backup klasörünü siliyoruz

# %%
# !ln -s /content/gdrive/"My Drive"/yolo_weights/backup /content/darknet/ # Drive içine backup adında klasör oluşturuyoruz ve buraya bağlıyoruz
# %pwd
# Out:
# '/content/darknet'

# %% [markdown]
# ###**Eğitim**

# %%
# !./darknet detector train data_ders/ders.data yolov4_ders.cfg /content/darknet/yolov4.conv.137 -map -dont_show
# Out:
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.056953), count: 1, class_loss = 4678.271973, iou_loss = 0.030273, total_loss = 4678.302246
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.434727), count: 10, class_loss = 1216.620605, iou_loss = 4.156494, total_loss = 1220.777100
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 161 Avg (IOU: 0.446682), count: 16, class_loss = 390.170166, iou_loss = 1.843079, total_loss = 392.013245
#  total_bbox = 652, rewritten_bbox = 0.000000 %
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 139 Avg (IOU: 0.000000), count: 1, class_loss = 4714.833984, iou_loss = 0.000000, total_loss = 4714.833984
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 150 Avg (IOU: 0.381989), count: 27, class_loss = 1271.556641, iou_loss = 10.337036, total_loss = 1281.893677
# ...

# %% [markdown]
# ###**Map Testi**

# %%
# !./darknet detector map data_ders/ders.data yolov4_ders.cfg /content/gdrive/MyDrive/yolov4_ders_best.weights
# Out:
#  CUDA-version: 11010 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 370, cudnn_half = 0, GPU: Tesla K80
# net.optimized_memory = 0
# mini_batch = 1, batch = 64, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    3 route  1 		                           ->  208 x 208 x  64
#    4 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    5 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    6 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    7 Shortcut Layer: 4,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
# ...

# %% [markdown]
# ###**Modelimizi Çalıştıralım**

# %%
# özel cfg'mizi test moduna ayarlamamız gerekiyor
# %cd  /content/darknet
# !sed -i 's/batch=64/batch=1/' yolov4_ders.cfg
# !sed -i 's/subdivisions=64/subdivisions=1/' yolov4_ders.cfg
# %cd ..
# Out:
# /content/darknet
# /content

# %% [markdown]
# ###**Test**

# %%
# %cd /content/darknet
# !./darknet detector test data_ders/ders.data yolov4_ders.cfg /content/gdrive/MyDrive/yolov4_ders_lastt.weights /content/609668.jpg -thresh 0.8
# Out:
# /content/darknet
#  CUDA-version: 11010 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 370, cudnn_half = 0, GPU: Tesla K80
# net.optimized_memory = 0
# mini_batch = 1, batch = 1, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    3 route  1 		                           ->  208 x 208 x  64
#    4 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    5 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    6 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
# ...
